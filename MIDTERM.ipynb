# %%
import pandas

# %%
df = pandas.read_csv('./2024ElectionOdds.csv')

df
# Out:
#           date  Donald Trump  Kamala Harris  Michelle Obama  Nikki Haley  \
# 0   21/11/2023          2.62          60.00            32.0         14.5
# 1   26/11/2023          2.58          65.00            29.0         13.5
# 2    3/12/2023          2.56          60.00            36.0         10.5
# 3   10/12/2023          2.44          55.00            40.0         13.5
# 4   17/12/2023          2.34          55.00            42.0         16.0
# 5   24/12/2023          2.44          55.00            50.0         10.0
# 6   31/12/2023          2.48          60.00            50.0          9.8
# 7    7/01/2024          2.54          65.00            50.0         10.0
# 8   14/01/2024          2.38          75.00            26.0         12.0
# 9   20/01/2024          2.32          75.00            24.0         22.0
# 10  27/01/2024          2.16          90.00            18.0         22.0
# 11   4/02/2024          2.22          70.00            17.0         22.0
# ...

# %%
df.loc[7:48, ["date", "Donald Trump", "Kamala Harris"]]
# Out:
#           date  Donald Trump  Kamala Harris
# 7    7/01/2024          2.54          65.00
# 8   14/01/2024          2.38          75.00
# 9   20/01/2024          2.32          75.00
# 10  27/01/2024          2.16          90.00
# 11   4/02/2024          2.22          70.00
# 12  10/02/2024          2.16          29.00
# 13  17/02/2024          2.30          32.00
# 14  25/02/2024          2.28          26.00
# 15   3/03/2024          2.08          40.00
# 16   9/03/2024          2.14          46.00
# 17  17/03/2024          2.06          50.00
# 18  23/03/2024          2.06          55.00
# 19  30/03/2024          2.22          46.00
# 20  14/04/2024          2.32          70.00
# 21  20/04/2024          2.28          70.00
# 22  28/04/2024          2.26          75.00
# 23   5/05/2024          2.18          70.00
# 24  12/05/2024          2.08          70.00
# 25  18/05/2024          1.92          85.00
# 26  26/05/2024          1.88          90.00
# ...

# %%
import matplotlib.pyplot as plt

names = ["Donald Trump", "Kamala Harris"]
popularity = [1.72, 2.42]  

plt.bar(names, popularity)  
plt.xlabel('Names')
plt.ylabel('Win')
plt.title('Leader Board Odds')
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 7, 13, 20, 28]
y1 = [1.98, 1.96, 2.14, 2.20, 2.10]  
y2 = [2.12, 2.14, 1.94, 1.88, 1.95] 

plt.plot(x, y1, label='Donald Trump', color='red')  

plt.plot(x, y2, label='Kamala Harris', color='blue')


plt.xlabel('September')
plt.ylabel('Odds')
plt.title('Election Betting Odds')

plt.legend()

plt.show()

# %%
df.loc[27:31, ["date", "Donald Trump", "Kamala Harris"]]
# Out:
#           date  Donald Trump  Kamala Harris
# 27   2/06/2024          1.96          100.0
# 28   9/06/2024          1.88           85.0
# 29  17/06/2024          1.80           60.0
# 30  23/06/2024          1.86           80.0
# 31  30/06/2024          1.64           30.0

# %%
import matplotlib.pyplot as plt

x = [2, 9, 17, 23, 30]
y1 = [1.96, 1.88, 1.80, 1.86, 1.64]  
y2 = [100.0, 85.0, 60.0, 80.0, 30.0] 

plt.plot(x, y1, label='Donald Trump', color='red')  

plt.plot(x, y2, label='Kamala Harris', color='blue')


plt.xlabel('June')
plt.ylabel('Odds')
plt.title('Election Betting Odds')

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt


labels = ['Michelle Obama', 'Donald Trump', 'Kamala Harris', 'Hillary Clinton', 'JD Vance']
sizes = [720.0, 17.2, 24.2, 550.0, 340.0 ] 
colors = ['gold', 'lightcoral', 'lightskyblue', 'lightgreen', 'purple']
explode = (0.1, 0, 0, 0, 0) 


plt.figure(figsize=(8, 6))
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Odds Percentages')
plt.show()
